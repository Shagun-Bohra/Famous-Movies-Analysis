# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movies_data = pd.read_csv("C:\\Users\\admin\\Desktop\\Startup\\movies (1)_SHAGUN.csv")

# %%
movies_data.head()
# Out:
#    Sn                                 Movie Name Release Year Studio Name  \
# 0   1                                       Dune         2021       PG-13
# 1   2                                 Squid Game         2021       TV-MA
# 2   3                                What If...?         2021       TV-14
# 3   4  Shang-Chi and the Legend of the Ten Rings         2021       PG-13
# 4   5                                   Free Guy         2021       PG-13
#
#   Duration (m)                         Genre  Rating  \
# 0          155      Action, Adventure, Drama     8.4
# 1           60      Action, Adventure, Drama     8.3
# 2          NaN  Animation, Action, Adventure     7.6
# 3          132    Action, Adventure, Fantasy     7.9
# 4          115     Action, Adventure, Comedy     7.4
#
#                                          Description
# 0  Feature adaptation of Frank Herbert's science ...
# 1  Hundreds of cash-strapped players accept a str...
# ...

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sn            10002 non-null  int64
#  1   Movie Name    10002 non-null  object
#  2   Release Year  9707 non-null   object
#  3   Studio Name   7719 non-null   object
#  4   Duration (m)  8546 non-null   object
#  5   Genre         10002 non-null  object
#  6   Rating        9330 non-null   float64
#  7   Description   10002 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 625.2+ KB

# %%
movies_data["Genre"].value_counts()
# Out:
# Action, Crime, Drama            1020
# Animation, Action, Adventure     800
# Action, Adventure, Drama         605
# Action, Adventure, Comedy        598
# Action, Adventure, Fantasy       408
#                                 ...
# Action, Family, Western            1
# Action, History, Horror            1
# Action, Crime, Music               1
# Drama, Action, Musical             1
# Action, Biography, Thriller        1
# Name: Genre, Length: 240, dtype: int64

# %%
labels= ['Action, Crime, Drama', 'Animation, Action, Adventure', 'Action, Adventure, Drama', 'Action, Adventure, Comedy', 'Action, Adventure, Fantasy']

colors=['blue', 'yellow', 'green', 'red', 'pink', 'orange']

sizes= [1020,800,605,598,408]

plt.pie(sizes,labels=labels, colors=colors, startangle=190, autopct='%2.2f%%')
plt.title('Genre wise movies distribution')

plt.axis('equal')

plt.show()

# %%
movies_data["Release Year"].value_counts()
# Out:
# 2021           526
# 2019           432
# 2018           390
# 2020           362
# 2017           301
#               ...
# (2000–2014)      1
# (1965–1968)      1
# (2000–2018)      1
# (1989–2020)      1
# (1987–1990)      1
# Name: Release Year, Length: 722, dtype: int64

# %%
labels= ['2021', '2020', '2019', '2018', '2017']

colors=['blue', 'yellow', 'green', 'red', 'pink']

sizes= [526,432,390,362,301]

plt.pie(sizes,labels=labels, colors=colors, startangle=190, autopct='%2.2f%%')
plt.title('Release Year wise movies distribution')

plt.axis('equal')

plt.show()

# %%
movies_data["Rating"].value_counts()
# Out:
# 6.6     309
# 6.4     287
# 6.5     286
# 6.7     283
# 6.2     283
#        ...
# 9.8       3
# 1.5       2
# 1.1       1
# 10.0      1
# 1.4       1
# Name: Rating, Length: 89, dtype: int64

# %%
labels= ['6.6', '6.4', '6.5', '6.5', '6.2']

colors=['blue', 'yellow', 'green', 'red', 'pink']

sizes= [309,287,286,283,283]

plt.pie(sizes,labels=labels, colors=colors, startangle=190, autopct='%2.2f%%')
plt.title('Rating wise movies distribution')

plt.axis('equal')

plt.show()

# %%
movies_data["Duration (m)"].value_counts()
# Out:
# 90     327
# 60     315
# 30     240
# 95     216
# 92     200
#       ...
# 310      1
# 285      1
# 197      1
# 245      1
# 261      1
# Name: Duration (m), Length: 254, dtype: int64

# %%
labels= ['90 min', '60 min', '30 min', '95 min', '92 min']

colors=['blue', 'yellow', 'green', 'red', 'pink']

sizes= [327,315,240,216,200]

plt.pie(sizes,labels=labels, colors=colors, startangle=190, autopct='%2.2f%%')
plt.title('Duration(min) wise movies distribution')

plt.axis('equal')

plt.show()

# %%
movies_data.plot(kind="scatter", x="Sn", y="Rating", alpha=0.8)
# Out:
# <AxesSubplot:xlabel='Sn', ylabel='Rating'>

# %%
from pandas.plotting import scatter_matrix
attributes = ["Sn", "Release Year", "Duration (m)", "Rating"]
scatter_matrix(movies_data[attributes], figsize = (12, 8))
# Out:
# array([[<AxesSubplot:xlabel='Sn', ylabel='Sn'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Sn'>],
#        [<AxesSubplot:xlabel='Sn', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Rating'>]], dtype=object)
